# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd
from sklearn import cluster

# %%
udf = pd.read_csv('../data/2nd/tianchi_mobile_recommend_train_user_filtered.csv', index_col=['user_id', 'item_id'])
u = udf.reset_index()

# %%
user_times_def = dict()
for h in xrange(24):
    user_times_def['h%02d'%h] = u[u.hour == h].groupby('user_id').behavior_type.size() / u.groupby('user_id').behavior_type.size()
utdf = pd.DataFrame(user_times_def).fillna(0)
utdf['label'] = [0] * len(utdf)

# %%
model = cluster.AffinityPropagation()
utdf['label'] = model.fit_predict(utdf.values[:, :-1])

# %%
model2 = cluster.KMeans(n_clusters=10)
utdf['mbkm'] = model.fit_predict(utdf.values[:, :-1])

# %%
cdf = pd.DataFrame(model2., columns=utdf.columns[:-2])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-ba0f565b7d96> in <module>()
# ----> 1 cdf = pd.DataFrame(model2.cluster_centers_, columns=utdf.columns[:-2])
#
# AttributeError: 'MiniBatchKMeans' object has no attribute 'cluster_centers_'

# %%
cdf.T.plot(figsize=(15, 5))

# %%
cdf.T.plot(figsize=(15, 5))

# %%
cdf.T.plot(figsize=(15, 5))

# %%
len(utdf[(utdf.label == 1)])
# Out:
# 402

# %%
cdf.T.plot(figsize=(15, 5))

# %%
cdf.T.plot(figsize=(15, 5))
